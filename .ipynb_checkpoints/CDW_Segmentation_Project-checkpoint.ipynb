# %%
import os
import json
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon

def visualize_image_with_annotations(image_path, annotation_path):
    """
    Show image with polygon annotations drawn from a JSON file (LabelMe format).
    """
    img = Image.open(image_path)
    
    with open(annotation_path, 'r') as f:
        annotation = json.load(f)

    plt.figure(figsize=(10, 10))
    plt.imshow(img)
    ax = plt.gca()

    for shape in annotation['shapes']:
        label = shape['label']
        points = shape['points']
        polygon = Polygon(points, closed=True, fill=False, edgecolor='red', linewidth=2, label=label)
        ax.add_patch(polygon)

    plt.title(f"Annotations for {os.path.basename(image_path)}")
    handles, labels = ax.get_legend_handles_labels()
    by_label = dict(zip(labels, handles))  # Remove duplicates
    plt.legend(by_label.values(), by_label.keys())
    plt.axis('off')
    plt.show()

folder = "Files"

image_file = os.path.join(folder, "2022_0001.jpg")
json_file = os.path.join(folder, "2022_0001.json")

visualize_image_with_annotations(image_file, json_file)

# %%
import os
import json
import numpy as np
from PIL import Image, ImageDraw

LABEL_MAP = {
    'BIN': 1,
    'HP': 2,
    'WT': 3,
    'CP': 4,
    'CB': 5,
    'FD': 6,
    'ST': 7,
    'FB': 8
}

# 📂 Folders
input_folder = "Files"
output_folder = "Masks"
os.makedirs(output_folder, exist_ok=True)

for filename in os.listdir(input_folder):
    if filename.endswith(".json"):
        json_path = os.path.join(input_folder, filename)
        with open(json_path, 'r') as f:
            data = json.load(f)
        
        img_width = data['imageWidth']
        img_height = data['imageHeight']
        mask = Image.new('L', (img_width, img_height), 0)  # 'L' for grayscale
        draw = ImageDraw.Draw(mask)

        for shape in data['shapes']:
            label = shape['label']
            points = shape['points']
            if label in LABEL_MAP:
                class_id = LABEL_MAP[label]
                draw.polygon(points, outline=class_id, fill=class_id)

        mask_name = filename.replace('.json', '.png')
        mask_path = os.path.join(output_folder, mask_name)
        mask.save(mask_path)

        print(f"Mask saved: {mask_path}")
# Out:
# Mask saved: Masks\2022_0001.png
# Mask saved: Masks\2022_0002.png
# Mask saved: Masks\2022_0003.png
# Mask saved: Masks\2022_0004.png
# Mask saved: Masks\2022_0005.png
# Mask saved: Masks\2022_0006.png
# Mask saved: Masks\2022_0007.png
# Mask saved: Masks\2022_0008.png
# Mask saved: Masks\2022_0009.png
# Mask saved: Masks\2022_0010.png
# Mask saved: Masks\2022_0011.png
# Mask saved: Masks\2022_0012.png
# Mask saved: Masks\2022_0013.png
# Mask saved: Masks\2022_0014.png
# Mask saved: Masks\2022_0015.png
# Mask saved: Masks\2022_0016.png
# Mask saved: Masks\2022_0017.png
# Mask saved: Masks\2022_0018.png
# Mask saved: Masks\2022_0019.png
# Mask saved: Masks\2022_0020.png
# Mask saved: Masks\2022_0021.png
# Mask saved: Masks\2022_0022.png
# Mask saved: Masks\2022_0023.png
# Mask saved: Masks\2022_0024.png
# Mask saved: Masks\2022_0025.png
# Mask saved: Masks\2022_0026.png
# Mask saved: Masks\2022_0027.png
# Mask saved: Masks\2022_0028.png
# Mask saved: Masks\2022_0029.png
# ...
